# %% [markdown]
# # California Housing Prices: Predicting with Linear Regression & Random Forest
#
# ## Introduction
# In this project, we will analyze and predict California housing prices using **Linear Regression** and **Random Forest**.
# We aim to understand how different features, such as **median income, house age, and population**, influence housing prices.
#
# We will follow these steps:
# 1. **Load and clean the dataset**
# 2. **Explore and visualize data**
# 3. **Train a Linear Regression model**
# 4. **Train a Random Forest model**
# 5. **Evaluate and compare model performance**

# %%
#we start by importing important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor

# %%
#load the data
data = pd.read_csv("housing.csv")
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
# checking for missing values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
# we observe that we have in fact some missing data in column 'total_bedrooms' and we need to fill or delete the lines with missing data in order
# to correctly train the models, for now, we are gonna choose to delete the lines

data.dropna(inplace = True)
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %% [markdown]
# ## 2. Explore and Visualize Data

# %%
#we can make a histogram of every column in the train_data

data.hist(figsize=(15, 7))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# we are also going to analyze correlations between the data.

data.drop(['ocean_proximity'], axis=1).corr() # since 'ocean_proximity' is not a numerical column, we need to drop it.
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924616           -0.109357     0.045480
# latitude            -0.924616  1.000000            0.011899    -0.036667
# housing_median_age  -0.109357  0.011899            1.000000    -0.360628
# total_rooms          0.045480 -0.036667           -0.360628     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.100270 -0.108997           -0.295787     0.857281
# households           0.056513 -0.071774           -0.302768     0.918992
# median_income       -0.015550 -0.079626           -0.118278     0.197882
# median_house_value  -0.045398 -0.144638            0.106432     0.133294
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.100270    0.056513      -0.015550
# latitude                 -0.066983   -0.108997   -0.071774      -0.079626
# housing_median_age       -0.320451   -0.295787   -0.302768      -0.118278
# total_rooms               0.930380    0.857281    0.918992       0.197882
# total_bedrooms            1.000000    0.877747    0.979728      -0.007723
# population                0.877747    1.000000    0.907186       0.005087
# households                0.979728    0.907186    1.000000       0.013434
# median_income            -0.007723    0.005087    0.013434       1.000000
# median_house_value        0.049686   -0.025300    0.064894       0.688355
#
#                     median_house_value
# longitude                    -0.045398
# latitude                     -0.144638
# housing_median_age            0.106432
# total_rooms                   0.133294
# total_bedrooms                0.049686
# population                   -0.025300
# households                    0.064894
# median_income                 0.688355
# median_house_value            1.000000

# %%
# if you're struggling to understand the correlation clearly, we can use a heatmap.  

plt.figure(figsize=(15,7))
sns.heatmap(data.drop(['ocean_proximity'], axis=1).corr(), annot = True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# We observe:
# - A strong correlation between **median_house_price** and **median_income**, which makes **median_income** an important predictor.
# - The correlation between **longitude** and **latitude** is strongly negative, meaning they do not provide useful information for prediction, so we will remove them.
# - Some variables, like **total_rooms**, **total_bedrooms**, and **households**, are highly correlated, which might cause multicollinearity. We will analyze and possibly drop some of them.
# - Intuitively, we will also include **`ocean_proximity`**, as it is likely strongly correlated with housing prices. However, this correlation does not appear in the heatmap since `ocean_proximity` is a categorical variable (strings). We will convert it into numerical form to use it in the model.

# %%
# checking the distribution of categories in the 'ocean_proximity' column  
data['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: count, dtype: int64

# %%
# transforming the string labeling in multi-class classification
data = data.join(pd.get_dummies(data['ocean_proximity']))
data = data.drop(['ocean_proximity'], axis=1)

data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 0           322.0       126.0         8.3252            452600.0      False
# 1          2401.0      1138.0         8.3014            358500.0      False
# 2           496.0       177.0         7.2574            352100.0      False
# 3           558.0       219.0         5.6431            341300.0      False
# 4           565.0       259.0         3.8462            342200.0      False
# ...           ...         ...            ...                 ...        ...
# 20635       845.0       330.0         1.5603             78100.0      False
# 20636       356.0       114.0         2.5568             77100.0      False
# 20637      1007.0       433.0         1.7000             92300.0      False
# 20638       741.0       349.0         1.8672             84700.0      False
# 20639      1387.0       530.0         2.3886             89400.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0       False   False      True       False
# 1       False   False      True       False
# 2       False   False      True       False
# 3       False   False      True       False
# 4       False   False      True       False
# ...       ...     ...       ...         ...
# 20635    True   False     False       False
# 20636    True   False     False       False
# 20637    True   False     False       False
# 20638    True   False     False       False
# 20639    True   False     False       False
#
# [20433 rows x 14 columns]

# %%
plt.figure(figsize=(15,7))
sns.heatmap(data.corr(), annot = True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
#we save a copy for another test with 'total_bedrooms' and 'total_rooms' and not 'bedrooms_per_room'
data_copy = data.copy()

# since total rooms and total bedrooms represent absolute counts, we will convert them into a ratio  
data['bedrooms_per_room'] = data['total_bedrooms'] / data['total_rooms']

# dropping total_rooms and total_bedrooms since their information is captured in the ratio
data = data.drop(columns=['total_rooms', 'total_bedrooms'])

#droping longitude and latitude because it can affect the model performance
data = data.drop(columns=['longitude', 'latitude'])
data_copy = data_copy.drop(columns=['longitude', 'latitude'])

data
# Out:
#        housing_median_age  population  households  median_income  \
# 0                    41.0       322.0       126.0         8.3252
# 1                    21.0      2401.0      1138.0         8.3014
# 2                    52.0       496.0       177.0         7.2574
# 3                    52.0       558.0       219.0         5.6431
# 4                    52.0       565.0       259.0         3.8462
# ...                   ...         ...         ...            ...
# 20635                25.0       845.0       330.0         1.5603
# 20636                18.0       356.0       114.0         2.5568
# 20637                17.0      1007.0       433.0         1.7000
# 20638                18.0       741.0       349.0         1.8672
# 20639                16.0      1387.0       530.0         2.3886
#
#        median_house_value  <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN  \
# 0                452600.0      False   False   False      True       False
# 1                358500.0      False   False   False      True       False
# 2                352100.0      False   False   False      True       False
# 3                341300.0      False   False   False      True       False
# 4                342200.0      False   False   False      True       False
# ...                   ...        ...     ...     ...       ...         ...
# 20635             78100.0      False    True   False     False       False
# 20636             77100.0      False    True   False     False       False
# 20637             92300.0      False    True   False     False       False
# 20638             84700.0      False    True   False     False       False
# 20639             89400.0      False    True   False     False       False
#
#        bedrooms_per_room
# 0               0.146591
# 1               0.155797
# 2               0.129516
# 3               0.184458
# 4               0.172096
# ...                  ...
# 20635           0.224625
# 20636           0.215208
# 20637           0.215173
# 20638           0.219892
# 20639           0.221185
#
# [20433 rows x 11 columns]

# %%
# we need to split the data into features (X) and target variable (Y)  
# this step is essential for training our models correctly.  

x = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

x
# Out:
#        housing_median_age  population  households  median_income  <1H OCEAN  \
# 0                    41.0       322.0       126.0         8.3252      False
# 1                    21.0      2401.0      1138.0         8.3014      False
# 2                    52.0       496.0       177.0         7.2574      False
# 3                    52.0       558.0       219.0         5.6431      False
# 4                    52.0       565.0       259.0         3.8462      False
# ...                   ...         ...         ...            ...        ...
# 20635                25.0       845.0       330.0         1.5603      False
# 20636                18.0       356.0       114.0         2.5568      False
# 20637                17.0      1007.0       433.0         1.7000      False
# 20638                18.0       741.0       349.0         1.8672      False
# 20639                16.0      1387.0       530.0         2.3886      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedrooms_per_room
# 0       False   False      True       False           0.146591
# 1       False   False      True       False           0.155797
# 2       False   False      True       False           0.129516
# 3       False   False      True       False           0.184458
# 4       False   False      True       False           0.172096
# ...       ...     ...       ...         ...                ...
# 20635    True   False     False       False           0.224625
# 20636    True   False     False       False           0.215208
# 20637    True   False     False       False           0.215173
# 20638    True   False     False       False           0.219892
# 20639    True   False     False       False           0.221185
#
# [20433 rows x 10 columns]

# %%
# split the data into train and test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %% [markdown]
# ## 3. Train a Linear Regression Model

# %%
regresion = LinearRegression()

# %%
regresion.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## 4. Train a Random Forest model

# %%
rd_forest = RandomForestRegressor()

# %%
rd_forest.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## 5. Evaluate and compare model performance

# %%
# model Scores (R² Score)
regresion_score = regresion.score(x_test, y_test)
rd_forest_score = rd_forest.score(x_test, y_test)

# making predictions
regresion_pred = regresion.predict(x_test)
rd_forest_pred = rd_forest.predict(x_test)

# mean Absolute Error (MAE)
regresion_mae = mean_absolute_error(y_test, regresion_pred)
rd_forest_mae = mean_absolute_error(y_test, rd_forest_pred)

print(f"Linear Regression:")
print(f"   - R² Score: {regresion_score:.4f}")
print(f"   - Mean Absolute Error (MAE): {regresion_mae:.4f}")

print("\nRandom Forest:")
print(f"   - R² Score: {rd_forest_score:.4f}")
print(f"   - Mean Absolute Error (MAE): {rd_forest_mae:.4f}")
# Out:
# Linear Regression:
#    - R² Score: 0.6418
#    - Mean Absolute Error (MAE): 50410.6552
#
# Random Forest:
#    - R² Score: 0.7161
#    - Mean Absolute Error (MAE): 43374.9560

# %% [markdown]
# ## Now, We Try Without the Ratio
#
# In this section, we will evaluate our models without using the **bedrooms_per_room** ratio. We will compare the performance to see if this feature has a significant impact on the results.

# %%
x = data_copy.drop(['median_house_value'], axis=1)
y = data_copy['median_house_value']

x
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    41.0        880.0           129.0       322.0
# 1                    21.0       7099.0          1106.0      2401.0
# 2                    52.0       1467.0           190.0       496.0
# 3                    52.0       1274.0           235.0       558.0
# 4                    52.0       1627.0           280.0       565.0
# ...                   ...          ...             ...         ...
# 20635                25.0       1665.0           374.0       845.0
# 20636                18.0        697.0           150.0       356.0
# 20637                17.0       2254.0           485.0      1007.0
# 20638                18.0       1860.0           409.0       741.0
# 20639                16.0       2785.0           616.0      1387.0
#
#        households  median_income  <1H OCEAN  INLAND  ISLAND  NEAR BAY  \
# 0           126.0         8.3252      False   False   False      True
# 1          1138.0         8.3014      False   False   False      True
# 2           177.0         7.2574      False   False   False      True
# 3           219.0         5.6431      False   False   False      True
# 4           259.0         3.8462      False   False   False      True
# ...           ...            ...        ...     ...     ...       ...
# 20635       330.0         1.5603      False    True   False     False
# 20636       114.0         2.5568      False    True   False     False
# 20637       433.0         1.7000      False    True   False     False
# 20638       349.0         1.8672      False    True   False     False
# 20639       530.0         2.3886      False    True   False     False
#
#        NEAR OCEAN
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 20635       False
# 20636       False
# 20637       False
# 20638       False
# 20639       False
#
# [20433 rows x 11 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
regresion2 = LinearRegression()
regresion2.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
rd_forest2 = RandomForestRegressor()
rd_forest2.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# model Scores (R² Score)
regresion_score = regresion2.score(x_test, y_test)
rd_forest_score = rd_forest2.score(x_test, y_test)

# making predictions
regresion_pred = regresion2.predict(x_test)
rd_forest_pred = rd_forest2.predict(x_test)

# mean Absolute Error (MAE)
regresion_mae = mean_absolute_error(y_test, regresion_pred)
rd_forest_mae = mean_absolute_error(y_test, rd_forest_pred)

print(f"Linear Regression:")
print(f"   - R² Score: {regresion_score:.4f}")
print(f"   - Mean Absolute Error (MAE): {regresion_mae:.4f}")

print("\nRandom Forest:")
print(f"   - R² Score: {rd_forest_score:.4f}")
print(f"   - Mean Absolute Error (MAE): {rd_forest_mae:.4f}")
# Out:
# Linear Regression:
#    - R² Score: 0.6396
#    - Mean Absolute Error (MAE): 49821.2492
#
# Random Forest:
#    - R² Score: 0.7154
#    - Mean Absolute Error (MAE): 42466.5069

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

def predict_house_price(features, model):
    features_array = np.array(features).reshape(1, -1)
    predicted_price = model.predict(features_array)[0]
    print(f"Predicted House Price: ${predicted_price:,.2f}")

# %%
# Features: [housing_median_age, population, households, median_income, <1H OCEAN, INLAND, ISLAND, NEAR BAY, NEAR OCEAN, ratio]
example_features = [30.0, 5000, 1000, 8.3252, 0, 1, 0, 0, 0, 0.5]  # Example with population and ratio  
# Features: [housing_median_age, total_rooms, total_bedrooms, population, households, median_income, <1H OCEAN, INLAND, ISLAND, NEAR BAY, NEAR OCEAN]
example_features2 = [30.0, 3500, 1000, 10000, 5, 8.3252, 0, 1, 0, 0, 0]  # Corrected total_bedrooms value  


predict_house_price(example_features, regresion)
predict_house_price(example_features, rd_forest)

predict_house_price(example_features2, regresion2)
predict_house_price(example_features2, rd_forest2)
# Out:
# Predicted House Price: $356,136.68
# Predicted House Price: $450,854.56
# Predicted House Price: $11,782.03
# Predicted House Price: $357,892.22
